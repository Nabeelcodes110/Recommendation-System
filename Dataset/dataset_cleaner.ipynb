# %%
import pandas as pd
import numpy as np 
import csv
from csv import writer
import uuid
import random

# %%
df = pd.read_csv('dataset2.csv')
df.tail()
# Out:
#       index                                            img_url  \
# 1135   6016  https://images.meesho.com/images/products/6454...
# 1136   6017  https://images.meesho.com/images/products/6231...
# 1137   6018  https://images.meesho.com/images/products/5204...
# 1138   6019  https://images.meesho.com/images/products/1210...
# 1139   6020  https://images.meesho.com/images/products/1496...
#
#                                                prod_url price  5  4  3  2  1  \
# 1135  https://www.meesho.com/aagam-fashionable-kurti...  ₹479  0  0  0  0  0
# 1136  https://www.meesho.com/chitrarekha-ensemble-ku...  ₹368  5  1  1  1  1
# 1137  https://www.meesho.com/aagyeyi-fashionable-kur...  ₹533  1  3  0  1  0
# 1138  https://www.meesho.com/abhisarika-graceful-kur...  ₹565  2  2  5  1  0
# 1139  https://www.meesho.com/chitrarekha-pretty-kurt...  ₹464  0  0  0  0  0
#
#       SUM prod_id
# 1135    0  12fesh
# 1136    9  113jdg
# 1137    5   uzidg
# 1138   10  201ubc
# 1139    0  2h4ic2

# %%
#generating 1000 users
users = []
for i in range(0,30000):
    users += [uuid.uuid4().hex]
users
# Out:
# ['8dce661076864623a54fb83ca5e248d8',
#  'c290d7b3b9ce43f19d6962a33c09af6c',
#  'f51097f16c68415caa1ab5116c2d4574',
#  'f9e95b11cf7c4b2f8cfa1dbef01540e7',
#  '9ca5552e734f42d5a06a30c891edd97c',
#  'b78f197747754ab992b9cc795804d902',
#  'd3421d1dbb6f4e338c7d6267ed788aab',
#  'ac7b7069dd714f168a30560f3c2b783d',
#  'cb1bf226ccdb415aa9d910055337b044',
#  'bc41ae71a4dc494bb02930dc83e4b661',
#  '3c348b8d75d845da8ccd92b0941dba38',
#  '27f97c2176254cf4845e6993d2a2a08e',
#  '73b35e49fe8c4055bdc5489266e270db',
#  '6be83c81d3404004bd480fe982f0df62',
#  '663dbabb8fe3486e93894f843bbff54e',
#  'c0de7199be864e81b907108803937efa',
#  '7410845f7cff48d2b27d3224655edd8e',
#  '0102d17893a7472ca31a6f6b5d95c577',
#  'eee8ea4682f04c0da04e8fcf4aa8cb56',
#  'e60198291ad44768955eaa9e89868546',
#  '1c3a86842dcc48a3bb9084978c2f5873',
#  'bc9cf2d63e39423393ddae3f85701ae4',
#  'f3b73a1e428b49ae8e24a7cff3df7a77',
#  '2f562015473a4329b7d32486681e1c8f',
#  '1758d4e84fef4ce99438cd0caa4c2a6a',
# ...

# %%
users[29999]
# Out:
# '23f88c03f96641e2a3a9c5b1cf52f2fb'

# %%
random.randint(1000000000 , 2000000000)
# Out:
# 1410669421

# %%
df.loc[0]['5']
# Out:
# 166

# %%
with open('kurtiData.csv', 'w' , encoding = 'utf-8' , newline='') as f:
    write = csv.writer(f)
    parameters = ['user_id' , 'product_id' ,'product_url', 'image_url', 'price' , 'rating' , 'timestamp']
    write.writerow(parameters)
    for i in range(0,1140):
        temp = set([])
        for j in range(0,df.loc[i]['5']):
            index = random.randint(0,29999)
            if(index not in temp):
                temp.add(index)
                user = users[index]
                product = df.loc[i]['prod_id']
                product_url=df.loc[i]['prod_url']
                image_url=df.loc[i]['img_url']
                price = df.loc[i]['price']
                timestamp = random.randint(1000000000 , 2000000000)
                rating = 5
                l5 = [user , product ,product_url, image_url, price , rating , timestamp]
                write.writerow(l5)
            else : continue
                
        for j in range(0,df.loc[i]['4']):
            index = random.randint(0,29999)
            if(index not in temp):
                temp.add(index)
                user = users[index]
                product = df.loc[i]['prod_id']
                product_url=df.loc[i]['prod_url']
                image_url=df.loc[i]['img_url']
                price = df.loc[i]['price']
                timestamp = random.randint(1000000000 , 2000000000)
                rating = 4
                l4 = [user , product ,product_url, image_url, price , rating , timestamp]
                write.writerow(l4)
            else : continue
        
        for j in range(0,df.loc[i]['3']):
            index = random.randint(0,29999)
            if(index not in temp):
                temp.add(index)
                user = users[index]
                product = df.loc[i]['prod_id']
                product_url=df.loc[i]['prod_url']
                image_url=df.loc[i]['img_url']
                price = df.loc[i]['price']
                timestamp = random.randint(1000000000 , 2000000000)
                rating = 3
                l3 = [user , product ,product_url, image_url, price , rating , timestamp]
                write.writerow(l3)
            else : continue
                
        for j in range(0,df.loc[i]['2']):
            index = random.randint(0,29999)
            if(index not in temp):
                temp.add(index)
                user = users[index]
                product = df.loc[i]['prod_id']
                product_url=df.loc[i]['prod_url']
                image_url=df.loc[i]['img_url']
                price = df.loc[i]['price']
                timestamp = random.randint(1000000000 , 2000000000)
                rating = 2
                l2 = [user , product ,product_url, image_url, price , rating , timestamp]
                write.writerow(l2)
            else : continue
                
                
        for j in range(0,df.loc[i]['1']):
            index = random.randint(0,29999)
            if(index not in temp):
                temp.add(index)
                user = users[index]
                product = df.loc[i]['prod_id']
                product_url=df.loc[i]['prod_url']
                image_url=df.loc[i]['img_url']
                price = df.loc[i]['price']
                timestamp = random.randint(1000000000 , 2000000000)
                rating = 1
                l1 = [user , product ,product_url, image_url, price , rating , timestamp]
                write.writerow(l1)
            else : continue

# %%
dataset = pd.read_csv('kurtiData.csv')
dataset.head()
# Out:
#                             user_id product_id  \
# 0  0b32cb93b4d1467a895fdd0c0fdcac7d     1xiamj
# 1  a546c81dcb9346619c00f3632bb39318     1xiamj
# 2  6f7480ff712d42eb9be53f37641a3bf9     1xiamj
# 3  cf05abc75bd74b159bc91a76ad4bfbb5     1xiamj
# 4  893a87b0ef41435cbd40f5065bdff448     1xiamj
#
#                                          product_url  \
# 0  https://www.meesho.com/alisha-refined-kurtis/p...
# 1  https://www.meesho.com/alisha-refined-kurtis/p...
# 2  https://www.meesho.com/alisha-refined-kurtis/p...
# 3  https://www.meesho.com/alisha-refined-kurtis/p...
# 4  https://www.meesho.com/alisha-refined-kurtis/p...
#
#                                            image_url price  rating   timestamp
# 0  https://images.meesho.com/images/products/1167...  ₹293       5  1816526580
# 1  https://images.meesho.com/images/products/1167...  ₹293       5  1431790209
# 2  https://images.meesho.com/images/products/1167...  ₹293       5  1455698017
# ...

# %%
# for i in range(0 , 12762):
#     dataset.loc[i][price] = dataset.loc[i]['price'].replace('₹','')
